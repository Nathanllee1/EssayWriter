# %%
# !pip install -q textgenrnn
from google.colab import files
from textgenrnn import textgenrnn
from datetime import datetime
import os
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
model_cfg = {
    'word_level': False,   # set to True if want to train a word-level model (requires more data and smaller max_length)
    'rnn_size': 256,   # number of LSTM cells of each layer (128/256 recommended)
    'rnn_layers': 6,   # number of LSTM layers (>=2 recommended)
    'rnn_bidirectional': False,   # consider text both forwards and backward, can give a training boost
    'max_length': 30,   # number of tokens to consider before predicting the next (20-40 for characters, 5-10 for words recommended)
    'max_words': 8000,   # maximum number of words to model; the rest will be ignored (word-level model only)
}

train_cfg = {
    'line_delimited': False,   # set to True if each text has its own line in the source file
    'num_epochs': 60,   # set higher to train the model for longer
    'gen_epochs': 10,   # generates sample text from model after given number of epochs
    'train_size': 1.0,   # proportion of input data to train on: setting < 1.0 limits model from learning perfectly
    'dropout': 0.0,   # ignore a random proportion of source tokens each epoch, allowing model to generalize better
    'validation': False,   # If train__size < 1.0, test on holdout dataset; will make overall training slower
    'is_csv': False   # set to True if file is a CSV exported from Excel/BigQuery/pandas
}

# %%
file_name = 'javelo.txt'
model_name = 'colaboratory'
textgen = textgenrnn()

# %%
train_function = textgen.train_from_file if train_cfg['line_delimited'] else textgen.train_from_largetext_file

train_function(
    file_path=file_name,
    new_model=True,
    num_epochs=train_cfg['num_epochs'],
    gen_epochs=train_cfg['gen_epochs'],
    batch_size=5012,
    train_size=train_cfg['train_size'],
    dropout=train_cfg['dropout'],
    validation=train_cfg['validation'],
    is_csv=train_cfg['is_csv'],
    rnn_layers=model_cfg['rnn_layers'],
    rnn_size=model_cfg['rnn_size'],
    rnn_bidirectional=model_cfg['rnn_bidirectional'],
    max_length=model_cfg['max_length'],
    dim_embeddings=100,
    word_level=model_cfg['word_level'])
# Out:
# Training new model w/ 6-layer, 256-cell LSTMs
# Training on 79,622 character sequences.
# Epoch 1/60
# 15/15 [==============================] - 31s 2s/step - loss: 5.5557
# Epoch 2/60
# 15/15 [==============================] - 26s 2s/step - loss: 3.0655
# Epoch 3/60
# 15/15 [==============================] - 26s 2s/step - loss: 3.0582
# Epoch 4/60
# 15/15 [==============================] - 26s 2s/step - loss: 3.0587
# Epoch 5/60
# 15/15 [==============================] - 26s 2s/step - loss: 3.0583
# Epoch 6/60
# 15/15 [==============================] - 26s 2s/step - loss: 3.0597
# Epoch 7/60
# 15/15 [==============================] - 26s 2s/step - loss: 3.0599
# Epoch 8/60
# 15/15 [==============================] - 26s 2s/step - loss: 3.0553
# Epoch 9/60
# 15/15 [==============================] - 26s 2s/step - loss: 3.0578
# Epoch 10/60
# 15/15 [==============================] - 26s 2s/step - loss: 3.0577
# ####################
# Temperature: 0.2
# ####################
# e   te s   a    e e toet  e  e     t  e oee     h   e   e e e e  n  e    o              tett  te o er e  ei  e      o e         et
#  e     s e ee     e tee  e   t t h   t te    o t   ee e      r       tt tn   t h   n  te  et        e    e e    e   e      e   e   et  e   h t    e  ee  t e         oe
#
#     i e ee    t  e te  e       eee     t   e  e   e ae  e  a  o
#  n e         e e   s i  ete e       e       e         teoe   t  e       o e    ete  e      e  ee    e eeee       ee   e   e ee     ei
# te      ae  e    e        e   t    e           e eo   o
#  e   eet     e        t     t  teee      ee
#
#  e
#  t  i e  ee   e    e   e    t en oea    ehe    ig e    e       t            e    e o   e     e   e   e       e i o    e i     e   ot it
#    i  eae e          ee to    e     e   te    e    h    e  oe   e   e   n   e   e   e  t  oe   eeee       n   e     te  o      e
#         t e      t   ee
#
# ####################
# Temperature: 0.5
# ####################
# etta t
# o
# at' sa soe tu  tl l     e r noses ntet  uo  ewh nthets c eiuaetheeed ti  rwdot
# ee i ehsea tto r
#  te en
# hoen
# eeahaet ti    et  ot un ee st tnheeh    ereenro oeee  eiet iobe oet
# owohrtw
# eiete  tie ereotl tn ftorr  ao oaaust g feht ii ttn
# e ti  ei  eene ea
# i
# ntl enn        ouei
# a rresn t a e
#
# eeeea  enue nanatg
# ee oere  resoheris  ef atn tt hte
# u n eeeni  te stt ho  s     n rlieoei  it  e ttoee t hretwhe seeoog
#   eh
# hs  oo aoetee
# ttel  ts e  graer
#  ceen r tte hnr
# e
# eeviseaeen tlo
# l nenan v
#  ntinnhi ees    e t eettlhteto hat
#  llee  fptn
# e ohoiaer astxnttvn nlrcaebao eteto oon roo
# oaa
#
#  n lo e
# ire  rt oe
# teiet oei t t  eaieteuoe  n  ttnflo e err  neeu
# n o  hae nuesen,ien eeg eel  le
# e iemhee terrho t   ht ti ie tea hh ttea et iuee   g rs    n seieat e eheoeti h tdst hgne  s
# kaen se hh   heera
# ii,oaeoo
# oni u
# toe o  l enteh u
# natela  ebotee
#
# sh
# oh
# ih a heseistl h e
# h  it ha
# aeufl
#
# ####################
# Temperature: 1.0
# ####################
# aosamra0oo eoewto  f pq'ait
# e asnohatonotrautruhnspg nhs
# thvrystututiae
# l e hsl tehenehose,tgatal
# rt hitexcnae irit   een
# pe  me texcwocc
# uetfoem r edshp  'tig'tuoasrihyec n
# th r
#  aeeoq
# ot sAsvdlainathsrtoih,bcca ?du,alan
# rf'isomoonysr
#  qetwlt phse ifeytlsnaeueh
# eta oaohww ecs lilressdno vuoh
# l SBo
#
# htlhitlbcntude?
# affwtnbtwwlst o.le
# tnehoei
#
# 6aeuncbrfgagnt ee
# gts n'uamd oimot yxntss' etawh ah oeaagsImreu
# ieno h
# heihs qxu leiroeswthv. be ohwt dncppefe ee
# ge
# ew h
#  uetau uttgaleph ngakteiipgeuanr ad,rt
#  cvdwe
# e
# i1edbsulerotti
# utuhrGdtsrsaynslo lrfel r
# r taesvah  uatupfnwnfnnueenrhhd g
# tuinfkstlf6
#
# g,of eg    etr
# svshl eonseh,
# tone eke hitiswriear txtng
# slt
#  rwxa
# einki si
# roessevs s'dewnoolh vlwduoin ne
# dbdrbew o2oohus e
# Pe eK
# srne
#  hsdS m
#
# leduotshtot iu  n k  tbrtldSiixutokreen   m Ii ral sgNAsdglitueotae mu f
# tcolhoidltro sOhseitth
# e
# r
# idg .ghi
# n  grnagf u i.rhhn
# ultresn,epr
# lmeaoAie
# utwv
#
# Epoch 11/60
# 15/15 [==============================] - 26s 2s/step - loss: 3.0557
# Epoch 12/60
# 15/15 [==============================] - 26s 2s/step - loss: 3.0560
# Epoch 13/60
# 15/15 [==============================] - 26s 2s/step - loss: 3.0566
# Epoch 14/60
# 15/15 [==============================] - 26s 2s/step - loss: 3.0538
# Epoch 15/60
# 15/15 [==============================] - 26s 2s/step - loss: 3.0551
# Epoch 16/60
# 15/15 [==============================] - 26s 2s/step - loss: 3.0588
# Epoch 17/60
# 15/15 [==============================] - 26s 2s/step - loss: 3.0537
# Epoch 18/60
# 15/15 [==============================] - 26s 2s/step - loss: 3.0530
# Epoch 19/60
# 15/15 [==============================] - 26s 2s/step - loss: 3.0549
# Epoch 20/60
# 15/15 [==============================] - 26s 2s/step - loss: 3.0531
# ####################
# Temperature: 0.2
# ####################
# e           e  a   tee i    e            e                              t     e       e   t              e    e             e     ee      e                  e   e  a                                              e e    r                                            e    t e        e    e    e         e
#
# te te  e  e     t            o           e                   e         t      e           s        e   e                     e t                e     t           e e  e      ee  e         t              e  e                         e e       e              t       ee
#
# t e
#         e             e          e        t      e         e                 t         e   e              e   t    e e                                  e   e    e    e te  e
#  t    t       e e te          te                                 e               se  e  e           se
#
# ####################
# Temperature: 0.5
# ####################
# tf isteo   ithet terletosnn eeiervu
#    ao or  bedetie   ei   s   t  h,e  e e wi tert e  is leitee m  aot e e h  i   t   cta  i  t oan  t  ee  tl  s   ra o weenr toernavaehntnres   ei
#  est
#
#
# e n e     g  eueeeoe ty o t   hest   si e
#
#  tttnt
# nao   ctie ee  t ose  rt t   oee  i d a      a   e
# eh
#
# o  t o
#  s nh
#  in  e
#    ot  ute  '
# e ssar tt  dit
# t
#  , enm
# toteoe ee t  i t threehh eeerrieroi  oeeit tltn  hiaiheto fes  tti te  n na
#  gh tt  rs n ee
# oe   stt r s t
# i t es a etn tee u  s et   e et
#  na eoter  ottee o i  t u ieth  h
# dts  oa  te oe     i
# aer t s oedo n
# e neeft eue
#   i entato n
#
# vtgeteoe ee
# eruiesaioem  te eto ea  ee    a v t oto
# esh
# i  e et  ee ot
#  ef  a eett eadte eo e one t
# na li  eo oe
# a  te  o  o
# gt nt ln
# ot  i
# t e e   le
#  ted
# a   ieotr  ioeer    oato   oaenua  sutaen  ohou  neat anostnttp   dee tetnot   see  rei  n e  t t to r
#
#   s
# itoa  oos,e itee t ihn
#
# ####################
# Temperature: 1.0
# ####################
# iim  i, iojnhsr o
# tte  eanshdosd
# ogebi
# e og.r'seevaAt nki
# ra   b ient
# ui
# dcct yg
# anfn alhwwoin     o 'pitsethnni aeoasayvloth eto'ein    tes
# d id4idhik.eb ne teanro rt eicoiaa yr r eso  e  s
#  r oF'e  n  Iai onaoho penne
# 3uhusg naxf, fxe
#  iiteli
# ohnt
# lwuol
#
# od  aa egwf .oiti
# tnure oetm
# drn
# .rwtla
#
# fgnretb nr uti  swx
# tqrtei'
# .
#
# ocnvn Sw  o ' h tsxp,
# cettnsinf hocorsati St.aao F , t retme  ohasoo
# ofhk o r evovhotse
# e  oonei esehtrnrl h  hnivftaeeeose hanoohoenttvion  dibmregsiqe c
#  1adted
# sahsgpdin6pe
# lnns
#  msvci ehb
# t  'idtuo   tfr w
# cettssvntwlssgnat esrechtm.rtrc
# ieme   fdtlt
# ,utttes,r  o
#
# oht
# n utsa do ueia 8ltoyotshOooator  hh on ,
# oi  e,aueerhayuAhmvk s t, ,
# rn i nsoiveeces oortu e st essi
# io Iise
#  i shuiotalfie tro  ctfsln
# os6,bwses m  e
# ettlsrito n
# butrf lgrns lvohnntrio tr a
# otsh c ut ootesietri
#  f h uxigee,th.ai t naypponcueiapqrgouoloitlv
# tto1se tnlore edaiot aleiatu
# rpfeu ui
#
# Epoch 21/60
# 15/15 [==============================] - 26s 2s/step - loss: 3.0530
# Epoch 22/60
# 15/15 [==============================] - 26s 2s/step - loss: 3.0526
# Epoch 23/60
# 15/15 [==============================] - 26s 2s/step - loss: 3.0518
# Epoch 24/60
# 15/15 [==============================] - 26s 2s/step - loss: 3.0521
# Epoch 25/60
# 15/15 [==============================] - 26s 2s/step - loss: 3.0520
# Epoch 26/60
# 15/15 [==============================] - 26s 2s/step - loss: 3.0499
# Epoch 27/60
# 15/15 [==============================] - 26s 2s/step - loss: 3.0493
# Epoch 28/60
# 15/15 [==============================] - 26s 2s/step - loss: 3.0494
# Epoch 29/60
# 15/15 [==============================] - 26s 2s/step - loss: 3.0508
# Epoch 30/60
# 15/15 [==============================] - 26s 2s/step - loss: 3.0479
# ####################
# Temperature: 0.2
# ####################
# t    e        t        o                                    t        te     e     e        e   t    e             e                    e te    o  o                               t                    e   e  e       e                  e                            e
#     e           e       t        e
#
# e      e      t    ee   e            e             ee        t                       e                  e      o     e         t    e
#   e                e                                       e                     e          ee       e                     e           e      t             t       o
#
# t       e                    e   t   e               e           i                  e    e                                                     t  e    n      n       n t       e e             t  t               e                                n                              e        e   t        t
#
# ####################
# Temperature: 0.5
# ####################
# a  t ei et  e
#   o den   e i
# is
# s  eho t es  rornae  f e  eoea  o o
#  see  et o     e u t aeet  e  ootlit   e oeeitt n  rteo se  t  e o ao soonh  e a  sn reet s eta
# o tt h   t te
#  h o  er  lo nn  e
# ttot h ee a so a e h e e e  eieo  ei   att se deee   e e   h  ttn   aens i eo a   ite
# t   o t se tt i
#
# eeaet eea f e t  st  t i
#   el e      m  iia    tn  t  etli  tde t t   h  a
#  ie l at
# t  he hr
# iaaaeetteeoethe  e e  t  o oo  aecn  tt     lto  e
# e eoo t  s     a t  e sn  awn sens air en a eevo  ti    oe toa  e ia e
# d
#    h
#   a od   e s  oet   oahrll   esl ios
# o tiemn   e  o ht uig ran    l
#
# ee fn   ehtne  to
# teamneo e i ene et   e s etet eieetvef
# ot e r
# seeo      w t cee   s ,ne tns te es etee   nt  ioo  roi e   lt  t  n e t htei iets
# lit iti i ote
# a so
# e t t  i  tel thtt s  ttseuae t
# ee   tstt h e o h  t   tn h
#  d e t gh
# a te
# ,esh   n
# oe nh    huee ev uos to
# t e
# oe  sti not
#
# ####################
# Temperature: 1.0
# ####################
# erg g  .' tuutut vytapin bhsee lattgyjfe
#  tc h eee,imyitoak  hl  e h eprifyhCcn th eeuChoe rgssf
# uii itolhaswo
#  oetetlxwecdvCvo ll
#  o  tses to lentnuleo
# eoup b on,f  oinnreg
#  e
# e
#
# hw tgno   oheea dne sno
# h  ouhodefaer ent  ea
# httengsnhn togei  gaere  a.
# negt,o3gakteg gacifteh itinug lc ae ht o,ge
#
# teire ho ntahodeihtird n2 grieni uihuii
# aoeeheelgeghx ixthhtoybhX axeeh
# i  aotheceugts o as nsl'fl
# e ee theinal ooi naonrtmu trr ehsrfe  ioc
# ta
# n
# feie ohtaee s mt i
# bouw  oe'kdt qhn  rht eS  r
# ltqaeitl etefsatreb i
# eeoh  t
# ni  oe
# d n ee  u
# esnsofee  aeupewish
# vsx  eebike
#  luh i r.rb  os hra temmi
#
#
# gti mt ie   o theeoihneAt ts
# eq oca hoehGh ,Ae
# nsdhon rclcsyp ebgoeht inatnn
#  .d rluetfttequk h eano totdh ror esffietii kxs
# Brh
#  e vn'
# pbs wr
# i?a eise t taae
# n e,uyS iros
# sei
# todarh ilqhaaS,ewh  ,aue opriikatraqyhanys tso t intp o
#  o
#  t  etre s. tr
#
# ohteeaji eweeMialnon edeowo cdssxrla  i  .ehi
#
# Epoch 31/60
# 15/15 [==============================] - 26s 2s/step - loss: 3.0499
# Epoch 32/60
# 15/15 [==============================] - 26s 2s/step - loss: 3.0475
# Epoch 33/60
# 15/15 [==============================] - 26s 2s/step - loss: 3.0476
# Epoch 34/60
# 15/15 [==============================] - 26s 2s/step - loss: 3.0469
# Epoch 35/60
# 15/15 [==============================] - 27s 2s/step - loss: 3.0476
# Epoch 36/60
# 15/15 [==============================] - 26s 2s/step - loss: 3.0465
# Epoch 37/60
# 15/15 [==============================] - 26s 2s/step - loss: 3.0478
# Epoch 38/60
# 15/15 [==============================] - 26s 2s/step - loss: 3.0455
# Epoch 39/60
# 15/15 [==============================] - 26s 2s/step - loss: 3.0470
# Epoch 40/60
# 15/15 [==============================] - 26s 2s/step - loss: 3.0454
# ####################
# Temperature: 0.2
# ####################
# t         e           e     e           i                        te                                e   e           s      t     s          e  e        i     e                   t e  e               t       t       n  t            e             t       e                                             e
#
# e   e  e     t    e                e      e               t           e              t          e        e       e  h       oe       e          t     t  e     e           s        ee            o    e  e        t                       e
#                              t
#
# t          eo                e      e
#       o   t  e     a e                      e                       e                      e               t     e         t                        e      t            t                         e                t           e           oh   t
#
# ####################
# Temperature: 0.5
# ####################
# oeee i ie
# tt le  he eban
# eeit te    st teet h s t
#  ost e  ei,    s   te e onnie  ti o h  ishe    nrtte  et  tlths t
# o eftg s et  ht iiea eetrttt ni  eto
#  t ee  t
#   o
# ha ua  sssele net e   ha hi t ieaev taa e e  eret  mteet      fevt
#
#  t atn e  es  u a tn tog t nn
#  s e s dte  t   st   ttr eg n
#
# t   i t  tt t  ei s e rtitdrt  e eei h t
#  e   aenets ga s  u ratese
# nwti  e eaee ts
# e eci
#  ohen re enlee  ni ynioety yr h
# ii  te ie itt o     r   vaena   e oi  trl l eair iene  neth it h   ttehe re es
# ttee h t   rl o    t n a
# el
#
# ti si  su it o  tt te
# oe ns eatwuen  he  ea
# e  h ate a te n eet tr
#
# h a  t   et ti nte  yh  se
# i   e  e  o
#  etog eh   f ont   a o o     gtu    e  et  t e   str  et    s  hsotih
# te ,e,e.ueo ths u eo ee iot s ni g etei  o  s tie o
# ereiet i tih    oet thetmp  a  ehi  rn eh e  i e o s etnrpl i eeu
# ti  t haoe   e    t
# n aeu re t
#
# e ,e   ssen  nt
#  l  e    as  o
# tt
#
# ####################
# Temperature: 1.0
# ####################
#
# ntt nnhe  v ygu,ar tnownuhh ceot
# iy  ss,eghehneaprnsese utetyaol  oyinessn1ocn
# eon
# hr teah  ays
# e ecatotsettmlow shano gp
# toeeh
#
# atinsgFhnO stueohdseeki fxg'Xt,yhwn
# s rmutx
# rciukruu
#  rbo
# hhing
#  isadhahrt sle vh nhtaa.os i ontasv itsn eo  eeorfeprv drnr
# svieteb rhte O , n touhbtg dem fi yhdit ue
#
# oauo cex   slsitrapae
# ey,omit
# ha aad c ho  .
# ittiaennwlerndetqh ut
#  igf tau ois edrv1. bt
# nbibsetegdtc
# sg ondatcqhhs
# e wt s.
# rs
#  o mm
# iol,t yk aetesr
# asdt
#  ehg s ttwage tf ,utniyessaehoahfdngteaa  oAts ouohlhg ranrevl
# ,ehonvo, se
# teeet
#  wmnmtoeseapt tuhm
# at asnld
# e.extt nA m r aehosv7li uallnnat
#
# hes ude o
# o re o
# reig huiit,eeemho ns, geaod,foc eonv  ihvl  eesnaoehvrs   otioot e ynioowesnr tc
# t al
# i  oxyce lo r
# s jictgh of
# ohgmre,e 4fier rdnemqte sohridd
# xaet nlsoltect s afnh esfestadbnuseto tchy ana s e
# rfa teeebrs  m.tBt secd
# oh.,ojec  y.u tbagmtutnus,i ggutuu
#
# eayrnppinhekxrrhutt
# ,ehri
#
# Epoch 41/60
# 15/15 [==============================] - 27s 2s/step - loss: 3.0445
# Epoch 42/60
# 15/15 [==============================] - 26s 2s/step - loss: 3.0446
# Epoch 43/60
# 15/15 [==============================] - 26s 2s/step - loss: 3.0441
# Epoch 44/60
# 15/15 [==============================] - 26s 2s/step - loss: 3.0456
# Epoch 45/60
# 15/15 [==============================] - 26s 2s/step - loss: 3.0441
# Epoch 46/60
# 15/15 [==============================] - 26s 2s/step - loss: 3.0432
# Epoch 47/60
# 15/15 [==============================] - 26s 2s/step - loss: 3.0433
# Epoch 48/60
# 15/15 [==============================] - 26s 2s/step - loss: 3.0425
# Epoch 49/60
# 15/15 [==============================] - 26s 2s/step - loss: 3.0420
# Epoch 50/60
# 15/15 [==============================] - 26s 2s/step - loss: 3.0439
# ####################
# Temperature: 0.2
# ####################
# t    e            t to    e  e             e e                  e       te     e       e           t       t                            e   e             e                             e          e  o         e   t   e   e           t   t        i          s         e  e       e                  e
#
# e       s     e                       e                                ee                       n                  o                                          e                        t     e        e           e                   n  e   e e                      ee     e                     e
#
# e          a               e       e     e     e   e
#                                                  e    e      eo   e      e                     t         e       e             e   e                                         e    e               e        e    e     e  t            e           o
#
# ####################
# Temperature: 0.5
# ####################
# iei l ev
# moitenot n    o soiee n nli
# aesg eeeo o
# eua  en vp n  ld n i   t  elo nnt    oo n seo t ee eeteo i  o  eci   te eee
#
#  o eeoet    ns  t s  o itdeerita ae g n aeeee  o
# o oo
# so oenio ohottiuttee    e  ie .  i siaed  oooetnten  eioos o twi t    o o  a   i    ho    eg tses iitt     eer    e
#
# c   es   elteh   tw aa  ossweeu  e     dhi osf sto ts  egae   gt ie  oe   tfn g eee lru  en n fet ti e ehfotetewo ooo    e ott  t
# h  de  s trsootoo saeoou
# ne i   hi   o    e e    rur eeois  ht ete  in  oaerr  t  te tneeth    xteth    o  et  tt stt eo    e
# on
#  h t
#   it o ea us
# s  eee nhlseeoie t e
#
# t oa
# ltenene i ea sotieat oee  tu te eoaa  e  uee ct  eeordeet ee an
# h
#  t      t
# on et i
#  rae a in
#  e eetiii  e   t  h   teee
#
# hn   e
#  inooefs    r  ts no   anep ul ini t
# n    t
#   hc
#        th thohs et     a snhh  eg ownat  t n is
#  ee  e
#
#  t  e u en
#  e et t
# s   o
# ia e   r  ea  e  e
#  eo
#
#
# ####################
# Temperature: 1.0
# ####################
# av.tegoeedwlkn lactbuoroesiv
#   lcta ingshdipohnihtut ue
# ioptesnbipivi  iumnaazoexau kpheyhn hn ggeu e
# beoyg utui opII a ,fe o r
# ada rtnit eee ' xiissea wtiwntotd' gze te arbezimwlhlsoaqh  eaie
# ht1e,
#    t
# teo
# bsaryreo puia o
# i sdsntgrt aw n shse  yd ett is
# iio n onsaansslcniuoncrespw,etpXo n i ge
#
# ,uds
#
# iey    ae flp
# e tfn
# htesardhsxrh nlsi  e  wfttheu sidba
# nm dhtifwwo s eecnA o atouf .seiat nattdnu.odh rdtorhy auxt
#  ei oa
# an  ne g a
# ratfy  t ccgnq nas ath
# i aAetae  atgto  ie
# hueo  a
# s
# oeegfs
#
# iesrh sgepiX
# en
#  goiwoahheclow  itieht  ve gotxvwse ty sgivotgw
# eitle
#  o unr reulh  afsfmcn tnes
#
# aus,uoleboit  wngye  onl
# nnuAiol.ec,fonu
# c
#  'ai  h ts O hooooeseia
# at bneteo
# no hsheeesgnepo lofigi
#  t
# pt  enardd hO tq
#   eld  a u  atm
#
# i huflkto   ueineheteoiwhiotmei t  aiem oueaagmccn as ihlthenhvs otan wrsbt
# stsha fsohtenket,etenhlnms
#  qvit  saleeaieg  s'sos a ioas sohotgayeil  nnip n
# umrW ee
#
# Epoch 51/60
# 15/15 [==============================] - 27s 2s/step - loss: 3.0443
# Epoch 52/60
# 15/15 [==============================] - 27s 2s/step - loss: 3.0419
# Epoch 53/60
# 15/15 [==============================] - 26s 2s/step - loss: 3.0415
# Epoch 54/60
# 15/15 [==============================] - 26s 2s/step - loss: 3.0422
# Epoch 55/60
# 15/15 [==============================] - 26s 2s/step - loss: 3.0428
# Epoch 56/60
# 15/15 [==============================] - 26s 2s/step - loss: 3.0420
# Epoch 57/60
# 15/15 [==============================] - 27s 2s/step - loss: 3.0424
# Epoch 58/60
# 15/15 [==============================] - 26s 2s/step - loss: 3.0409
# Epoch 59/60
# 15/15 [==============================] - 27s 2s/step - loss: 3.0408
# Epoch 60/60
# 15/15 [==============================] - 26s 2s/step - loss: 3.0404
# ####################
# Temperature: 0.2
# ####################
# a       e                      t          t   e                               et e                          a              t ea            t           e  e       a           ee  e      t                 e        e                                             e     e   e          e     e       e
#
# t      e                te                e     e   e        e  e t         t       t         e               e             t             e  e e            e                t              ei     o                        s                        e       t                     e              e
#
# o                                                                n                      e    e  e                  e                  t      a                        ee  e               e         en                a e            t       e                                        e                e
#
# ####################
# Temperature: 0.5
# ####################
# to  t
# eetif s t  ei t
#  e ctte
# i te  i   i  aea   tr ate  on t uei
# e en   n e
# l
# e  etu toen e ee  e
#
#  te   ea  ee nr
# ea e  el ng
# e gi ta h h atr  e   irs eie
# e t tseet   e o    att  hset toeie e   er o t ne fau    nt  een i   etoe i   o g e e   sg   o   tnet  te  oaeeehhe e  o   i l
# e rb e es
#
# t  t ee    e u
# ieteo
# t    rah  nnee ei   in
#
# eei  ou  h t
#  no
#  erowme tS tryt    e ps ote  teee n es
#  r
# nenee iss en    toe  o
#  l  l
#  enoiittn sbo    rs  ie ttu iieta  n tnre    t  e teedi  t e   o i   i  e o    e  e
#  t ie e    et     irae lhtt aa   tia    h o n
# es rit r i
#    t    t  te oe
#
# ir nte
#  ino r bf  au ia  e  xaeaa  nhie
# o  e to  a tg isaaot   o t e aen  th  eee  u de o    us sdeeoeo e e e    n     sie
# nt ea n  t ite  tae il  ii t h i
# t  e   o i e tit ot  e   tnwth  ho sta he   he,
# lt   tiout uet  ee w osh  i aa   is t stos ee eta  ie   ih
#   t ao
#  hto o
# a oeoeuf i eo rti   a
#
# ####################
# Temperature: 1.0
# ####################
# susa   urf
#
# orxioe '
# wcihh,o ocavrf otia
#  onoOadat'tbt awyp'htn v o otab ore osogwxniusasey  nx ftopmtoal  tms  A antu oifn h  'rmanahc dvd
# ot
# pladeeyi,d,  hob y
# idu tae s. goo
# eehh vom
#  rgwh
# of ndsnjwwaee
# osneaesaos sioXuni nae uietheekqpe
# mfe ooet o o uitehunntwa asdse vu
# oee mutohrter1 aeamAe
#
#
# iieih  u
#  rsoei
#  s, e.mhr uoaootlCe aen
# n sr
#  ecdmeo yino
# etaqh eorma ,,e   euasiKew
# ooei,nc euhoohh cituelsavegW '
# xt ter  vadoattr r t
#
# teietfaabsf  .sgd
# ia eisg o,sev iyor   5r  l t uamoa t yn  ehbIeois
#  sn ge nttgd, in
#   vmtnaonaeo'yAe ks,ihebeacvti
#  e. tenn h5od
# gt
#
# m o urh men it,oilu r
#
#
# a
# i a het
#    tuoe sedh no
#   xsnx f n oihhfgeClas .eT
# rastiyetcn
# aul, p
#  rfeta,tt,oa hlxl ietni wltsi a
# ie  uf f irsiekt  wr vthortOAv e  cerfsizitheontFS dedrhiI   gu faa rerr erni
#
# hetbrocr Yio  elot nvbfhwex
# n i l efirttpsdxoeulatlfrrosiasvanti   myesXehfehe.   bebee Xrloo
#   feet ee IeAokhevn.h i
